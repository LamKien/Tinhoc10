# %% [markdown]
# ---
# # **BÀI 6 CẤU TRÚC RẼ NHÁNH**
#
# ---

# %% [markdown]
# ## **YÊU CẦU BÀI HỌC**
# * Nhận biết được các phép tính logic
# * Tạo các biểu thức logic thể hiện điều kiện rẽ nhánh trong chường trình
# * Viết được câu lệnh rẽ nhánh trong Python

# %% [markdown]
# ## **CẤU TRÚC RẼ NHÁNH LÀ GÌ ?**
# > Cấu trúc rẽ nhánh trong mô tả thuật toán thể hiện một hành động có được thực hiện hay không được thực hiện phụ thuộc vào điều kiện có được thỏa mãn hay không
# <br> <br>
# > Theo em cách giải phương trình bậc 2 có sử dụng cấu trúc rẽ nhánh hay không? Nếu có hãy cho biết điều kiện rẽ nhánh và hành động thực hiện ứng với các chường hợp?

# %% [markdown]
# ## **1. CẤU TRÚC RẼ NHÁNH TRONG MÔ TẢ THUẬT**

# %% [markdown]
#  * Cấu trúc <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Ví dụ <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. ĐIỀU KIỆN RẼ NHÁNH**
# * *`<Điều kiện>`* trong thuật toán là một biểu thực nhận giá trị **logic** (True/False)
# * các **phép so sánh** thường được dùng để biểu diễn *`<điều kiện>`*

# %% [markdown]
# * Dưới đây là bảng các phép so sánh sử dụng trong Python <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Một vài ví dụ về biểu thức so sánh trong mục dưới dây <br>*(Nhấn vào ![image.png](data:image/png;base64,...) để chạy các lệnh)*

# %%
# Ví đụ 1 (SGD - Cánh diều)
a=12
b=10

# %%
a<b

# %%
a*a+b*b<=100

# %%
a+5!=b

# %%
2*a==b

# %% [markdown]
# * Kết hơp nhiều phép so sánh để tạo thành *`<điều kiện>`* phức tạp <br>

# %%
#Ví dụ 2(SGK - Cánh diều)
a=5
b=10

# %%
(a<b)and(a+5!=b)

# %%
(3*a>b)or(2*a==b)

# %%
not(a*a+b*b<=100)

# %% [markdown]
# ## **3. CÂU LỆNH RẼ NHÁNH TRONG PYTHON**
# > Hai loại cấu trúc rẽ nhánh đó là rẽ nhánh dạng thiếu và dạng đầy đủ

# %% [markdown]
# * **Dạng Thiếu**
# ![image.png](data:image/png;base64,...)
# > Hãy thực hiện thử các đoạn mã dưới dây

# %%
# Ví dụ 3 (SGK - Cánh diều)
# Đưa ra thông báo 
# nến t không phải là số có 2 chữ số
t=11
if t<10:
  print(t,'Không phải là số có hai chứ số')

# %%
# Đưa ra thông báo nếu k là số âm
k=-1
if k<0: 
  print(k,'là số âm')

# %%
# Phương trình ax^2 +bx+c=0
a=3
b=4
c=2
delta=a*a - 4*a*c
if delta<0:
  print('phương trình vô nghiệm')

# %% [markdown]
# * **Dạng đủ**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * **Hoạt động**
# ![image.png](data:image/png;base64,...)

# %%
# Hay chạy thử chương trình
a=int(input('Nhập vào mọt số nguyên: '))
if a%2==0:
  print(a,'là số chẵn.')
else:
  print(a,'là số lẻ.')

# %%
# Ví dụ 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
c=int(input('Tổng sản lượng cà phê: '))
a=int(input('Sản lượng cà phê Arabica: '))
if a/c>=0.1:
  print('Arabica được mùa.')
  hs=2
else:
  print('Arabica mất mùa.')
  hs=3
print('Hệ số giá bán: ',hs)

# %%
# Một Ví dụ nữa 
# Kiểm tra xem học sinh có được tuyển sinh 
# vào lớp 10 hay không (không tính điểm liệt)
điểm_chuẩn=13.50
tổng_điểm=float(input('Nhập tổng điểm: '))
if tổng_điểm>=điểm_chuẩn:
  print('Bạn đã trúng tuyển vào lớp 10')
else:
  print('Bạn không được tuyển vào lớp 10')

# %% [markdown]
# ## **4. BÀI TẬP LUYỆN TẬP**

# %% [markdown]
# **Bài tập 1**<br>
# ![image.png](data:image/png;base64,...)

# %%
# Hoàn thiện đoạn mã trong hình 8a vào dưới dây

# %% [markdown]
# **Bài tập 2**<br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết mã chương trình bài tập vào đây

# %% [markdown]
# **Bài tập vận dung**<br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết mã chương trình vào đây

# %% [markdown]
# ---
# # **BÀI 7 THỰC HÀNH CẤU TRÚC RẼ NHÁNH**
# ---

# %% [markdown]
# ## **YÊU CẦU BÀI HỌC**
# *   Viết chương trình đơn giản có sử dụng cấu trúc rẽ nhánh

# %% [markdown]
# ## **Bài tập 1** Lấy ví dụ về câu lệnh if <br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết mã Ví dụ 1 vào đây

# %%
# Viết mã Ví dụ 2 vào đây

# %% [markdown]
# ## **Bài tập 2** Chia kẹo <br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết chương trình và chạy thử ở đây

# %% [markdown]
# ## **Bài tập 3** Tìm lỗi sai<br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hướng dẫn: Viết lại chương trình và sửa lỗi, ghi chú trình bày lỗi sai sau dấu #

# %% [markdown]
# **a. Chương trình của Bình** <br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết chương trình và chạy thử ở đây

# %% [markdown]
# **b. Chương trình của An**<br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết chương trình và chạy thử ở đây

# %% [markdown]
# **c. Chương trình của Phúc** <br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết chương trình và chạy thử ở đây

# %% [markdown]
# ## **Bài tập 4** Tìm số lớn nhất <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em hãy đọc hiếu sơ đồ, viết lại chương trình và thực hiện chương trình với bộ dữ liệu khác nhau <br> ![image.png](data:image/png;base64,...)

# %%
# Viết chương trình và chạy thử ở đây

# %% [markdown]
# **Bài tập vận dụng**<br>
# ![image.png](data:image/png;base64,...)

# %%
# Viết chương trình và chạy thử ở đây
